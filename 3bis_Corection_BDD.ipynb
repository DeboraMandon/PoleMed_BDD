# %%
import pandas as pd
import glob
import numpy as np
import re
import getpass

# %% [markdown]
# # Ajouter les nouvelles données du planning

# %%
# utilisateurs
username = getpass.getuser()

# %%
df1=pd.read_excel('ao.xlsx', header=None)
df2=pd.read_excel('cds.xlsx', header=None)
df3=pd.read_excel('rru.xlsx', header=None)
df4=pd.read_excel('art.xlsx', header=None)
df5=pd.read_excel('pds.xlsx', header=None)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       120 non-null    object
#  1   1       394 non-null    object
#  2   2       395 non-null    object
#  3   3       395 non-null    object
#  4   4       394 non-null    object
#  5   5       394 non-null    object
#  6   6       395 non-null    object
#  7   7       395 non-null    object
#  8   8       395 non-null    object
#  9   9       0 non-null      float64
#  10  10      40 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 34.1+ KB

# %%
df2.head()
# Out:
#             0        1         2          3                     4       5  \
# 0  09/01/2023  Interne     MUTIN      David     d.mutin@imadis.fr    Lyon
# 1         NaN  Associé   BOUQUET   Gregoire   g.bouquet@imadis.fr    Lyon
# 2         NaN  Associé   HISSIER     Julien   j.hissier@imadis.fr  Rennes
# 3         NaN  Associé    POULIN  Alexandre    a.poulin@imadis.fr  Rennes
# 4         NaN  Associé  KOUBAITY       Omar  o.koubaity@imadis.fr    Lyon
#
#          6                    7                    8            9
# 0  Journée  09/01/2023 08:00:00  09/01/2023 13:00:00          NaN
# 1  Journée  09/01/2023 08:00:00  09/01/2023 13:00:00  Chef de CDS
# 2  Journée  09/01/2023 08:00:00  09/01/2023 13:00:00          NaN
# 3  Journée  09/01/2023 08:00:00  09/01/2023 13:00:00          NaN
# 4  Journée  09/01/2023 09:00:00  09/01/2023 14:00:00          NaN

# %%
correspondance_colonnes = {0 : 'Date',
                          1: 'Associé',
                          2: 'Nom',
                          3 : 'Prénom',
                          4 : 'mail',
                          5 : 'Site',
                          6 : 'Jour/Nuit',
                          7: 'Date_Heure_Début',
                          8 : 'Date_Heure_Fin'}

df1 = df1.rename(columns=correspondance_colonnes)
df3 = df3.rename(columns=correspondance_colonnes)

# %%
correspondance_colonnes = {0 : 'Date',
                          1: 'Associé',
                          2: 'Nom',
                          3 : 'Prénom',
                          4 : 'mail',
                          5 : 'Site',
                          6 : 'Jour/Nuit',
                          7: 'Date_Heure_Début',
                          8 : 'Date_Heure_Fin',
                          9 : 'Chef'}

df2 = df2.rename(columns=correspondance_colonnes)

# %%
correspondance_colonnes = {0 : 'Date',
                          1: 'Associé',
                          2: 'Nom',
                          3 : 'Prénom',
                          4 : 'mail',
                          5 : 'Site',
                          6 : 'Jour/Nuit',
                          7: 'Date_Heure_Début',
                          8 : 'Date_Heure_Fin',
                          9 : 'Chef',
                          10 : 'Formation'}

df2 = df2.rename(columns=correspondance_colonnes)
df5 = df5.rename(columns=correspondance_colonnes)
df4 = df4.rename(columns=correspondance_colonnes)

# %%
df1['Chef'] = np.nan
df3['Chef'] = np.nan
df4['Chef'] = np.nan

df1['Formation'] = np.nan
df2['Formation'] = np.nan
df3['Formation'] = np.nan
df4['Formation'] = np.nan

# %%
df1['Source'] = 'AO'
df2['Source'] = 'CDS'
df3['Source'] = 'RRU'
df4['Source'] = 'ART'
df5['Source'] = 'PDS'

# %%
df1['Nom_Prenom'] = df1['Nom']+' '+df1['Prénom']
df2['Nom_Prenom'] = df2['Nom']+' '+df2['Prénom']
df3['Nom_Prenom'] = df3['Nom']+' '+df3['Prénom']
df4['Nom_Prenom'] = df4['Nom']+' '+df4['Prénom']
df5['Nom_Prenom'] = df5['Nom']+' '+df5['Prénom']

# %%
df1 = df1.dropna(subset=['Nom_Prenom'])
df2 = df2.dropna(subset=['Nom_Prenom'])
df3 = df3.dropna(subset=['Nom_Prenom'])
df4 = df4.dropna(subset=['Nom_Prenom'])
df5 = df5.dropna(subset=['Nom_Prenom'])

# %%
df4.head()
# Out:
#          Date  Associé        Nom   Prénom                  mail  Site  \
# 0  09/01/2023  Interne    BOUCHET   Marion   m.bouchet@imadis.fr  Lyon
# 1         NaN  Interne    RAMIREZ    Laura   l.ramirez@imadis.fr  Lyon
# 2         NaN  Interne     MAYARD  Charles    c.mayard@imadis.fr  Lyon
# 3  10/01/2023  Interne    RAMIREZ    Laura   l.ramirez@imadis.fr  Lyon
# 4         NaN  Interne  BOU HARB    Daniel  d.bou-harb@imadis.fr  Lyon
#
#   Jour/Nuit     Date_Heure_Début       Date_Heure_Fin  Chef  Formation Source  \
# 0   Journée  09/01/2023 08:00:00  09/01/2023 13:00:00   NaN        NaN    ART
# 1   Journée  09/01/2023 13:00:00  09/01/2023 19:00:00   NaN        NaN    ART
# 2      Nuit  09/01/2023 19:00:00  10/01/2023 01:00:00   NaN        NaN    ART
# 3   Journée  10/01/2023 08:00:00  10/01/2023 13:00:00   NaN        NaN    ART
# 4   Journée  10/01/2023 13:00:00  10/01/2023 19:00:00   NaN        NaN    ART
#
#          Nom_Prenom
# 0    BOUCHET Marion
# 1     RAMIREZ Laura
# 2    MAYARD Charles
# 3     RAMIREZ Laura
# 4  BOU HARB  Daniel

# %%
df1['Date'] = df1['Date'].fillna(method='ffill')
df2['Date'] = df2['Date'].fillna(method='ffill')
df3['Date'] = df3['Date'].fillna(method='ffill')
df4['Date'] = df4['Date'].fillna(method='ffill')
df5['Date'] = df5['Date'].fillna(method='ffill')

# %%
df1=df1.drop(['Nom', 'Prénom'], axis=1)
df2=df2.drop(['Nom', 'Prénom'], axis=1)
df3=df3.drop(['Nom', 'Prénom'], axis=1)
df4=df4.drop(['Nom', 'Prénom'], axis=1)
df5=df5.drop(['Nom', 'Prénom'], axis=1)

# %%
df1['Date'] = pd.to_datetime(df1['Date'], format='%d/%m/%Y')
df2['Date'] = pd.to_datetime(df2['Date'], format='%d/%m/%Y')
df3['Date'] = pd.to_datetime(df3['Date'], format='%d/%m/%Y')
df4['Date'] = pd.to_datetime(df4['Date'], format='%d/%m/%Y')
df5['Date'] = pd.to_datetime(df5['Date'], format='%d/%m/%Y')

# %%
df1['Date_Heure_Début'] = pd.to_datetime(df1['Date_Heure_Début'],format="%d/%m/%Y %H:%M:%S")
df2['Date_Heure_Début'] = pd.to_datetime(df2['Date_Heure_Début'],format="%d/%m/%Y %H:%M:%S")
df3['Date_Heure_Début'] = pd.to_datetime(df3['Date_Heure_Début'],format="%d/%m/%Y %H:%M:%S")
df4['Date_Heure_Début'] = pd.to_datetime(df4['Date_Heure_Début'],format="%d/%m/%Y %H:%M:%S")
df5['Date_Heure_Début'] = pd.to_datetime(df5['Date_Heure_Début'],format="%d/%m/%Y %H:%M:%S")

# %%
df1['Date_Heure_Fin'] = pd.to_datetime(df1['Date_Heure_Fin'],format="%d/%m/%Y %H:%M:%S")
df2['Date_Heure_Fin'] = pd.to_datetime(df2['Date_Heure_Fin'],format="%d/%m/%Y %H:%M:%S")
df3['Date_Heure_Fin'] = pd.to_datetime(df3['Date_Heure_Fin'],format="%d/%m/%Y %H:%M:%S")
df4['Date_Heure_Fin'] = pd.to_datetime(df4['Date_Heure_Fin'],format="%d/%m/%Y %H:%M:%S")
df5['Date_Heure_Fin'] = pd.to_datetime(df5['Date_Heure_Fin'],format="%d/%m/%Y %H:%M:%S")

# %%
df1['Heure_Début'] = df1['Date_Heure_Début'].dt.strftime('%H:%M:%S')
df2['Heure_Début'] = df2['Date_Heure_Début'].dt.strftime('%H:%M:%S')
df3['Heure_Début'] = df3['Date_Heure_Début'].dt.strftime('%H:%M:%S')
df4['Heure_Début'] = df4['Date_Heure_Début'].dt.strftime('%H:%M:%S')
df5['Heure_Début'] = df5['Date_Heure_Début'].dt.strftime('%H:%M:%S')

# %%
df1['Heure_Fin'] = df1['Date_Heure_Fin'].dt.strftime('%H:%M:%S')
df2['Heure_Fin'] = df2['Date_Heure_Fin'].dt.strftime('%H:%M:%S')
df3['Heure_Fin'] = df3['Date_Heure_Fin'].dt.strftime('%H:%M:%S')
df4['Heure_Fin'] = df4['Date_Heure_Fin'].dt.strftime('%H:%M:%S')
df5['Heure_Fin'] = df5['Date_Heure_Fin'].dt.strftime('%H:%M:%S')

# %%
df1['Horaire'] = df1['Heure_Début']+' - '+df1['Heure_Fin']
df2['Horaire'] = df2['Heure_Début']+' - '+df2['Heure_Fin']
df3['Horaire'] = df3['Heure_Début']+' - '+df3['Heure_Fin']
df4['Horaire'] = df4['Heure_Début']+' - '+df4['Heure_Fin']
df5['Horaire'] = df5['Heure_Début']+' - '+df5['Heure_Fin']

# %%
dfs = [df1, df2, df3, df4, df5]

# Concaténez les DataFrames de la liste en utilisant la fonction concat()
concatenated_df = pd.concat(dfs)

# Réinitialisez l'index du DataFrame concaténé
concatenated_df.reset_index(drop=True, inplace=True)

# %%
concatenated_df['Date'] = concatenated_df['Date'].dt.strftime("%d/%m/%Y")

# %%
concatenated_df.sample(10)
# Out:
#             Date  Associé                     mail        Site Jour/Nuit  \
# 5877  01/05/2023  Associé    c.chevalier@imadis.fr  St etienne   Journée
# 5628  22/04/2023  Interne     l.meinsohn@imadis.fr      Rennes      Nuit
# 2930  24/01/2023  Associé       a.mayaud@imadis.fr  St etienne      Nuit
# 1352  24/01/2023  Associé        r.peyre@imadis.fr   Marseille      Nuit
# 57    22/04/2023  Associé     e.stephant@imadis.fr    Bordeaux      Nuit
# 3758  20/02/2023  Associé  l.malaureille@imadis.fr        Lyon      Nuit
# 196   20/01/2023  Interne   e.beaufreton@imadis.fr      Rennes   Journée
# 2360  16/04/2023  Interne          p.roy@imadis.fr        Lyon   Journée
# 2212  03/03/2023  Interne         m.roux@imadis.fr        Lyon   Journée
# 2679  16/01/2023  Interne       b.marchi@imadis.fr   Marseille      Nuit
#
#         Date_Heure_Début      Date_Heure_Fin          Chef Formation Source  \
# 5877 2023-05-01 12:00:00 2023-05-01 20:00:00           NaN       NaN    PDS
# 5628 2023-04-22 20:00:00 2023-04-23 08:00:00           NaN       NaN    PDS
# 2930 2023-01-24 20:00:00 2023-01-25 08:00:00  Chef de site       NaN    PDS
# 1352 2023-01-24 13:00:00 2023-01-24 15:00:00           NaN       NaN    RRU
# 57   2023-04-22 18:00:00 2023-04-23 08:00:00           NaN       NaN     AO
# 3758 2023-02-20 20:00:00 2023-02-21 08:00:00           NaN       NaN    PDS
# 196  2023-01-20 17:00:00 2023-01-20 18:00:00           NaN       NaN    CDS
# 2360 2023-04-16 13:00:00 2023-04-16 19:00:00           NaN       NaN    ART
# 2212 2023-03-03 13:00:00 2023-03-03 19:00:00           NaN       NaN    ART
# 2679 2023-01-16 20:00:00 2023-01-17 08:00:00           NaN       NaN    PDS
#
#               Nom_Prenom Heure_Début Heure_Fin              Horaire
# 5877   CHEVALIER Clément    12:00:00  20:00:00  12:00:00 - 20:00:00
# 5628     MEINSOHN Ludwig    20:00:00  08:00:00  20:00:00 - 08:00:00
# 2930    MAYAUD Alexandre    20:00:00  08:00:00  20:00:00 - 08:00:00
# 1352          PEYRE Rémi    13:00:00  15:00:00  13:00:00 - 15:00:00
# 57         STEPHANT Eric    18:00:00  08:00:00  18:00:00 - 08:00:00
# 3758   MALAUREILLE Lison    20:00:00  08:00:00  20:00:00 - 08:00:00
# 196   BEAUFRETON Edouard    17:00:00  18:00:00  17:00:00 - 18:00:00
# 2360      ROY Philippine    13:00:00  19:00:00  13:00:00 - 19:00:00
# 2212         ROUX Maxime    13:00:00  19:00:00  13:00:00 - 19:00:00
# 2679     MARCHI Baptiste    20:00:00  08:00:00  20:00:00 - 08:00:00

# %%
concatenated_df.to_csv('data 01-05_2023.csv', index=False)

# %%
import pandas as pd
import glob
import numpy as np
import re

# %%
df1=pd.read_csv('C:/Users/'+username+'/Imadis Téléradiologie/INTRANET - IMADIS/QUALITE/7- RHM/15 - DMA/GitHub/data/Concat_df.csv')
df2=pd.read_csv('data 01-05_2023.csv')

# %%
df1.sample(5)
# Out:
#       Source       Nom_Prenom        Date Heure_Début Heure_Fin  \
# 6637     PDS  Nguyen Anh quoc  22/09/2020    20:00:00  08:00:00
# 24259    PDS   ACQUIER Adrien  01/04/2022    18:00:00  21:00:00
# 31422    PDS     CADOUR Farah  24/09/2022    08:00:00  20:00:00
# 21641    PDS     CUINET Marie  20/09/2021    18:00:00  20:00:00
# 22618    PDS    VATELE Jordan  31/10/2021    19:00:00  08:00:00
#
#                    Horaire     Date_Heure_Début       Date_Heure_Fin  \
# 6637   20:00:00 - 08:00:00  2020-09-22 20:00:00  2020-09-23 08:00:00
# 24259  18:00:00 - 21:00:00  2022-01-04 18:00:00  2022-01-04 21:00:00
# 31422  08:00:00 - 20:00:00  2022-09-24 08:00:00  2022-09-24 20:00:00
# 21641  18:00:00 - 20:00:00  2021-09-20 18:00:00  2021-09-20 20:00:00
# 22618  19:00:00 - 08:00:00  2021-10-31 19:00:00  2021-11-01 08:00:00
#
#              Associé                 mail       Site Jour/Nuit          Chef  \
# 6637             NaN                  NaN        NaN       NaN           NaN
# 24259  Futur Associé  a.acquier@imadis.fr  Marseille   Journée           NaN
# 31422          Thèsé   f.cadour@imadis.fr  Marseille   Journée  Chef de site
# 21641        Associé   m.cuinet@imadis.fr       Lyon   Journée           NaN
# 22618          Thèsé   j.vatele@imadis.fr       Lyon      Nuit  Chef de site
#
#       Formation
# 6637        NaN
# 24259       NaN
# 31422       NaN
# 21641       NaN
# 22618       NaN

# %%
df1 = df1[~((df1['Date'] >= '2023-01-09') & (df1['Date'] <= '2023-05-08'))]

# %%
dfs = [df1, df2]

# Concaténez les DataFrames de la liste en utilisant la fonction concat()
data = pd.concat(dfs)

# Réinitialisez l'index du DataFrame concaténé
data.reset_index(drop=True, inplace=True)

# %%
data=data.drop_duplicates()

# %%
data.sample(3)
# Out:
#       Source           Nom_Prenom        Date Heure_Début Heure_Fin  \
# 333       AO        Muller Arnaud  17/09/2020    20:00:00  08:00:00
# 36870    PDS       DELEAU Florian  23/04/2023    08:00:00  20:00:00
# 34646    PDS  GUERARD Anne-sophie  19/01/2023    19:00:00  20:00:00
#
#                    Horaire     Date_Heure_Début       Date_Heure_Fin Associé  \
# 333    20:00:00 - 08:00:00  2020-09-17 20:00:00  2020-09-18 08:00:00     NaN
# 36870  08:00:00 - 20:00:00  2023-04-23 08:00:00  2023-04-23 20:00:00   Thèsé
# 34646  19:00:00 - 20:00:00  2023-01-19 19:00:00  2023-01-19 20:00:00   Thèsé
#
#                        mail      Site Jour/Nuit Chef Formation
# 333                     NaN       NaN       NaN  NaN       NaN
# 36870    f.deleau@imadis.fr  Bordeaux   Journée  NaN       NaN
# 34646  as.guerard@imadis.fr    Rennes   Journée  NaN       NaN

# %%
data.to_csv('Concat_df.csv', index=False)
